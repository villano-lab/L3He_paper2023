# %%
import numpy as np
from sympy import symbols
import math
import cmath 

import matplotlib as mpl
from matplotlib import pyplot as plt 

from scipy.stats import norm
import seaborn as sb 

import lmfit as lf
import scipy.optimize as opt 

from scipy.optimize import curve_fit  

from scipy import special

# %%
def normal_distribution(E,N,E1,o): 
    return N*(np.exp(-((E - E1)**2) / (2 * (o**2))))

# %%
N= 1
E= 10
E1= 10
o= 1 

#E_range=np.linspace(0,100,101) 
E_range = np.linspace(E1 - 5 * o, E1 + 5 * o, 1000)
#print(E_range)

# %%
pdf_values = normal_distribution(E_range,5,E1, o) 

plt.plot(E_range, pdf_values)
plt.xlabel('Energy (E)')
plt.ylabel('Probability Density')
plt.title('Normal Distribution Function')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
def normal_distribution2(EE2,N,E2,o2): 
    return N*(np.exp(-((EE2 - E2)**2) / (2 * (o2**2))))

# %%
N2= 1
EE2= 4
E2= 4
o2= 1

#E_range=np.linspace(0,100,101) 
E_range2 = np.linspace(E2 - 5 * o2, E2 + 5 * o2, 1000)
#print(E_range)

# %%
pdf_values2 = normal_distribution(E_range2,5,E2, o2) 
scaling_factor= 2
pdf_values_scaled = pdf_values2 * scaling_factor

plt.plot(E_range2, pdf_values_scaled)
plt.xlabel('Energy (E)')
plt.ylabel('Probability Density')
plt.title('Normal Distribution Function')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.subplot(121)
plt.plot(E_range, pdf_values)
plt.xlabel('Plot 1') 

plt.subplot(122)
plt.plot(E_range2, pdf_values2)
plt.xlabel('Plot 2') 

plt.suptitle("Multiple Graphs")
plt.show()

# %%
plt.plot(E_range, pdf_values) 
plt.plot(E_range2, pdf_values2)

plt.show()

# %%
plt.plot(E_range, pdf_values, label=f'E1 = {E1}, σ = {o}')
plt.plot(E_range2, pdf_values_scaled, label=f'E1 = {E2}, σ = {o2}')

plt.xlabel('Energy (E)')
plt.ylabel('Probability Density')
plt.title('Normal Distribution Functions')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Uniform Distribution

# %%
num_samples=1000 

U= np.random.uniform(0, 1, num_samples) 

print(U)

plt.plot(U)
# Out:
# [7.55600473e-01 8.91958735e-01 9.07196441e-01 6.68685267e-01
#  7.51232920e-01 6.88160016e-01 5.34006482e-01 9.45436495e-01
#  8.75908142e-01 4.19969174e-01 6.12105337e-01 9.62916578e-01
#  1.53284942e-01 6.83985869e-01 1.79436796e-01 2.31205093e-01
#  6.91597034e-01 7.27558994e-01 6.71281549e-03 6.70800738e-01
#  6.89538855e-01 5.28121091e-01 7.58748930e-02 4.24709161e-01
#  5.89359776e-01 1.07246751e-01 7.93093757e-01 5.96156889e-01
#  1.50073704e-01 9.33841773e-01 4.92597929e-01 9.11727386e-01
#  3.61990411e-01 8.64864700e-01 7.47341337e-01 6.51121382e-01
#  5.95906930e-01 2.84004260e-01 1.34442242e-01 6.00517491e-01
#  2.80668088e-01 3.43518051e-01 7.98626252e-01 7.68291177e-01
#  6.35621067e-01 1.75133171e-01 5.77388994e-01 3.99753719e-01
#  2.40628182e-01 8.70176163e-01 7.72147057e-01 6.31982035e-01
#  3.11685354e-01 7.16559089e-01 5.46099472e-02 7.85095824e-01
#  4.85745120e-03 7.45806819e-01 6.50767036e-01 5.10644497e-01
#  1.86697828e-01 4.98306954e-01 8.95059001e-02 2.87613912e-01
#  7.22904000e-01 4.01811542e-01 7.87832085e-01 3.11464976e-01
#  3.05747060e-01 8.06814702e-01 8.82428146e-01 7.91851097e-01
#  5.61009800e-01 1.03900575e-01 4.08203452e-02 6.17371681e-01
#  6.64399172e-02 4.62046236e-01 8.44455809e-01 1.48141420e-01
#  1.97739904e-01 6.39891005e-01 4.58038922e-01 3.76569889e-01
#  2.00866896e-01 6.42421581e-01 7.73903772e-01 1.56520694e-01
#  6.18611191e-01 9.84218897e-01 6.49753886e-01 6.85679689e-01
#  6.80904651e-01 4.38538766e-01 9.46043118e-01 5.90177742e-01
#  7.85635179e-01 8.53155892e-01 6.85593681e-01 6.89362496e-01
#  7.53676644e-01 4.10862600e-01 2.25238633e-01 2.66072747e-01
#  5.51316420e-01 4.45242574e-01 5.33676191e-01 9.83806822e-01
#  1.87581918e-01 2.91993706e-01 9.68455508e-02 5.99921854e-01
#  4.41923588e-01 9.65010686e-01 4.18598957e-01 5.02927977e-01
#  1.24695016e-01 2.38950041e-01 7.35715985e-01 7.47754910e-01
#  3.33622524e-01 3.42465265e-01 8.09446925e-01 7.85030531e-01
#  7.52450993e-01 6.27890248e-01 9.49166365e-02 6.25114279e-01
#  7.20311824e-01 1.04972301e-01 4.57867828e-01 3.68472100e-01
#  9.01480862e-01 7.22213763e-02 7.18939770e-01 8.56755907e-01
#  9.03305565e-01 6.11120726e-01 1.80857940e-03 6.57486889e-02
#  9.86678898e-01 5.74280610e-01 4.16152440e-01 4.84790732e-01
#  3.11720065e-01 3.26731284e-01 8.33975608e-01 1.35131491e-01
#  6.70855522e-01 7.46713250e-01 7.50663523e-01 8.03805666e-03
#  6.93703406e-02 1.33425880e-01 1.74738992e-01 1.10265918e-01
#  1.88840270e-01 8.47279348e-01 2.57316270e-01 3.66237960e-01
#  6.37674634e-01 5.79073697e-03 4.24701987e-01 5.25045924e-01]

# %% [markdown]
# ### Histograms

# %%
#Histogram 
num_samples=1000000

nbins=np.linspace(0,14,num=40)

U= np.random.uniform(0, 7, num_samples) 
mean_energy = 5
std_deviation = 1.25

mean_energy2 = 10
std_deviation2 = 1
#N=np.random.normal(E_range,pdf_values, num_samples) 
#N2=np.random.normal(E_range2,pdf_values2, num_samples) 

N=np.random.normal(mean_energy, std_deviation, num_samples) 
N2=np.random.normal(mean_energy2, std_deviation2, num_samples)

fig,axes = plt.subplots(1,1,figsize=(10.0,10.0),sharex=True)
plt.hist(U, bins=nbins, color='blue',alpha=1)

plt.hist(N2, bins=nbins, color='blue',label='Background Radiation',alpha=1)  

plt.hist(N, bins=nbins, color='green',label='Neutron Peak',alpha=0.7) 

ymin = 0
ymax = 150 

xmin=0

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('Neutron Peak With Background Radiation',fontsize=20)
plt.xlabel('Energy (MeV)',fontsize=20)
plt.ylabel('Frequency',fontsize=20) 

plt.legend(loc=2,prop={'size':14})
#plt.savefig('2DPlot1.png')
plt.show()

# %%
#Histogram 
num_samples=1000000

nbins=np.linspace(0,14,num=40)

U= np.random.uniform(0, 7, num_samples) 
mean_energy = 6
std_deviation = 1.35

mean_energy2 = 10
std_deviation2 = 1
#N=np.random.normal(E_range,pdf_values, num_samples) 
#N2=np.random.normal(E_range2,pdf_values2, num_samples) 

N=np.random.normal(mean_energy, std_deviation, num_samples) 
N2=np.random.normal(mean_energy2, std_deviation2, num_samples)

fig,axes = plt.subplots(1,1,figsize=(10.0,10.0),sharex=True)
plt.hist(U, bins=nbins, color='blue',alpha=1)

plt.hist(N2, bins=nbins, color='blue',alpha=1)  

plt.hist(N, bins=nbins, color='blue',alpha=1) 

ymin = 0
ymax = 150 

xmin=0

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('Overall Detection Distribution',fontsize=20)
plt.xlabel('Energy (MeV)',fontsize=20)
plt.ylabel('Frequency',fontsize=20) 

#plt.savefig('2DPlot2.png')
plt.show()

# %%
#Histogram 
num_samples=1000 

nbins=np.linspace(0,14,num=40)

U= np.random.uniform(0, 7, num_samples) 
mean_energy = 4
std_deviation = 1 

mean_energy2 = 10
std_deviation2 = 1

N=np.random.normal(mean_energy, std_deviation, num_samples) 
N2=np.random.normal(mean_energy2, std_deviation2, num_samples)

fig,axes = plt.subplots(1,1,figsize=(10.0,10.0),sharex=True)
plt.hist(U, bins=nbins, color='blue',alpha=0.7)

plt.hist(N, bins=nbins, color='green',alpha=0.7) 

plt.hist(N2, bins=nbins, color='red',alpha=0.7)  

Total= np.concatenate((U,N,N2))  
plt.hist(Total, bins=nbins, color='orange',alpha=0.7) 

print(np.shape(U)) 
print(np.shape(N)) 
print(np.shape(N2)) 
print(np.shape(Total)) 


ymin = 0
ymax = 150 

xmin=0
 
plt.title('Random Normal and Uniform Distribution')
plt.xlabel('Energy (MeV)')
plt.ylabel('Frequency') 

plt.show()
# Out:
# (1000,)
# (1000,)
# (1000,)
# (3000,)

# %%
#complamentry erf+1

# %%
erf=math.erf 
print(erf(1))
# Out:
# 0.8427007929497149

# %%
x = np.linspace(0,E_range)
plt.plot(x, special.erfc((x-5)/2)*30)
plt.xlabel('$x$')
plt.ylabel('$erfc(x)$')
plt.show()

# %%
pdf_values = normal_distribution(E_range,5,E, o) 
scaling_factor= 1
pdf_values_scaled= pdf_values * scaling_factor 
 
pdf_values2 = normal_distribution(E_range2,5,E2, o2)     
scaling_factor2=1
pdf_values_scaled2= pdf_values2 * scaling_factor2

# %%
A=pdf_values_scaled

B=pdf_values_scaled2

plt.plot(A) 

plt.plot(B)

# %%
A=plt.plot(E_range, pdf_values)
B=plt.plot(E_range2, pdf_values2)
C=plt.plot(x, special.erfc((x-5)/2)*3)
plt.show()

# %% [markdown]
# ## Organized

# %%
def error_function(x): 
    return special.erfc(((x-5)/2)*3)

# %%
def total_function (x): 
    return (normal_distribution(E,E1,o))+(normal_distribution2(EE2,E2,o2))+(error_function(x))

# %%
x = np.linspace(0, 20, 1000)

# Calculate y values for each function
y1 = normal_distribution(x,5,10,1)
y2 = normal_distribution2(x,5,4,1)
y3 = error_function(x)

# Plot the normal distributions on the primary y-axis
fig, ax1 = plt.subplots()

color = 'tab:blue'
ax1.set_xlabel('X')
ax1.set_ylabel('Normal Distribution ', color=color)
ax1.plot(x, y1+y2+y3, color=color)
ax1.tick_params(axis='y', labelcolor=color)


# Add legend
plt.legend()

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
